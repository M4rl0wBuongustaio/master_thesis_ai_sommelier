# %%
import sqlite3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.family'] = 'Palatino'
fig_path = '/Users/leonbecker/Library/CloudStorage/OneDrive-UniversitätWürzburg/Universität Würzburg/Master Information-Systems/Thesis/Abbildungen'

# %%
con = sqlite3.connect('wine.db')
cur = con.cursor()
df = pd.read_sql_query("SELECT * from wine", con)
df.head()
# Out:
#    index    id                                 name   price  type_id  \
# 0      0   590                           Chardonnay   29.95        2
# 1      1  1151       Brut (Chardonnay - Pinot Noir)   16.90        3
# 2      2  1155  Brut Rosé (Chardonnay - Pinot Noir)   23.85        4
# 3      3  1156                 Brut Blanc De Blancs   23.70        3
# 4      4  1213           Vin Santo di Montepulciano  158.00        7
#
#    is_natural    winemaker                      region             country  \
# 0           0    Bernardus             Monterey County  Vereinigte Staaten
# 1           0  Graham Beck                   Robertson           Südafrika
# 2           0  Graham Beck                   Robertson           Südafrika
# 3           0  Graham Beck                   Robertson           Südafrika
# 4           0   Avignonesi  Vin Santo di Montepulciano             Italien
#
#        grapes  average_rating  has_valid_ratings
# 0  Chardonnay             4.3                  1
# ...

# %%
df[df.price <= 150].groupby(by='type_id').boxplot(column='price')
plt.tight_layout()
